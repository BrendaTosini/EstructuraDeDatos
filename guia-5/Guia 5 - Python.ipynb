# %% [markdown]
# #### Universidad Nacional de Tres de Febrero
#
# ### Estructuras de Datos
#
# ## Guía de ejercicios 5 - Introducción a Python

# %% [markdown]
# ## Tipos básicos
#
# Investigar los métodos y operaciones que soportan los tipos básicos de Python y la precedencia de los operadores:
#
# > Ver https://docs.python.org/3/library/stdtypes.html

# %% [markdown]
# ## Realizar los siguientes cálculos en python
#
# a) $2^{1024}$

# %%
2**1024

# %% [markdown]
# b) 8 / 2 * (2 + 2)

# %% [markdown]
# ¿Porqué el resultado es **16** y no **1**?

# %% [markdown]
# c) Representar $0,53125$ como fracción

# %% [markdown]
# d) Calcular el cuadrado del módulo de $(3+2j)$

# %% [markdown]
# e) Calcular la parte entera y el resto de $181 \div 11$

# %% [markdown]
# ## Cadenas de caracteres

# %% [markdown]
# a) ¿Qué imprimirá el siguiente fragmento de código?

# %%
a = 3
saludo = 'Hola Mundo'
print(saludo * a)

# %% [markdown]
# - Insertar un fin de línea en saludo para que lo imprima en tres líneas

# %% [markdown]
# b) Dado el siguiente fragmento de código realizar lo siguiente:

# %%
texto = "En estructura de datos usamos java como lenguaje de programación"

# %% [markdown]
# - Reemplazar _java_ por _python_ en texto

# %% [markdown]
# - Devolver la subcadena con los últimos 3 caracteres de `texto`

# %% [markdown]
# - Ejecutar el siguiente fragmento de código y justificar el resultado:

# %%
texto[-2] = '-'

# %% [markdown]
# - Calcular en que posición comienza la palabra _python_

# %% [markdown]
# - Capitalizar el texto (poner la primera letra de cada palabra en mayúsculas)

# %% [markdown]
# - Calcular de que tipo es la variable `texto`

# %% [markdown]
# - Investigar la ayuda para la función `join` que soporta `texto`

# %% [markdown]
# ## Funciones

# %% [markdown]
# a) Programar una función que reciba un valor en grados Fharenheit y devuelva el equivalente en grados Celsius.
#
# Luego escribir un fragmento de código que utilice la función anterior e imprima una tabla de conversión desde 0ºF hasta 120ºF con incrementos de 10.
#
# La fórmula de conversión es la siguiente:
#
# $$
# F=\frac{3}{5} \times C+32
# $$

# %% [markdown]
# b) Dadas las siguientes funciones:

# %%
def cuad(x):
    return x * x


def cubo(x):
    return x * x * x

# %% [markdown]
# Escribir una función que use `cuad` y `cubo` y calcule $x^6$

# %% [markdown]
# c) Escribir una función que reciba una palabra o frase y que devuelva `True` si es un palíndromo
#
# >ver  https://es.wikipedia.org/wiki/Palíndromo

# %%
def palindromo(frase):
    pass

# %% [markdown]
# Probar la función creada con las siguientes frases:

# %%
frases=["acaso hubo buhos aca",
        "acaso hubo búhos acá",
        "a la catalana banal atacala",
        "A la catalana banal atacala",
        "arriba birra",
        "birra arriba",
        "a ti no bonita",
        "neuquen",
        "alli ves a sevilla",
        "aman a panama",
        "la ruta natural"]

for frase in frases:
    print("{: >30}   {:}".format(frase, palindromo(''.join(frase.split()))))

# %% [markdown]
# ## Listas, diccionarios y tuplas

# %% [markdown]
# 1. Dada una lista de números enteros escribir una función que:
#
#     a. Devuelva una lista con todos los números que sean primos. Usar dicha función para calcular los números primos entre 1 y 100

# %% [markdown]
# b. Devuelva la suma y el promedio de todos los números de la lista

# %% [markdown]
# c. Devuelva una lista con el factorial de cada uno de los números de la lista original.

# %% [markdown]
# d. Reciba la lista y un número $k$ y devuelva tres listas: una con los números menores a $k$, otra con los números iguales a $k$ y la tercera con los mayores que $k$ (¿Cómo se hace para que devuelva tres listas?)

# %% [markdown]
# 2. Dada una cadena de caracteres escribir una función que:
#
#     a. Devuelva un diccionario con la frecuencia de aparición de cada caracter

# %% [markdown]
# b. Devuelva un diccionario cuyas claves sean las vocales y los valores, listas de palabras que empiecen con la vocal indicada

# %% [markdown]
# 3. Suponer una lista con datos de las compras hechas por clientes de una empresa a lo largo de un mes, la cual contiene tuplas con información de cada venta: `(cliente, dia_del_mes, monto, domicilio_del_cliente)`.
#
#     Ejemplo:
#
#     ```
#     [("Nuria Costa", 5, 12780.78, "Calle Las Flores 355"), ("Jorge Russo", 7, 699, "Mirasol 218"),
#     ("Nuria Costa", 7, 532.90, "Calle Las Flores 355"), ("Julián Rodriguez", 12, 5715.99, "La Mancha 761"),
#     ("Jorge Russo", 15, 958, "Mirasol 218")]
#     ```
#
#     Escribir una función que reciba como parámetro una lista con el formato mencionado anteriormente y retorne los domicilios de cada cliente al cual se le debe enviar una factura de compra. Notar que cada cliente puede haber hecho más de una compra en el mes, por lo que la función debe retornar una estructura que contenga cada domicilio una sola vez.

# %% [markdown]
# 4. Escribir un programa que permita procesar datos de pasajeros de viaje en una lista de tuplas con la siguiente forma:
# `(nombre, dni, destino)`.
#
#     Ejemplo:
#
#     ```
#     [("Manuel Juarez", 19823451, "Liverpool"), ("Silvana Paredes", 22709128, "Buenos Aires"),
#     ("Rosa Ortiz", 15123978, "Glasgow"), ("Luciana Hernandez", 38981374, "Lisboa")].
#     ```
#
#     Además, en otra lista de tuplas se almacenan los datos de cada ciudad y el país al que pertenecen.
#
#     Ejemplo:
#
#     ```
#     [("Buenos Aires","Argentina"), ("Glasgow","Escocia"), ("Lisboa", "Portugal"),
#     ("Liverpool","Inglaterra"), ("Madrid","España")]
#     ```
#
#     Hacer un menú iterativo que permita al usuario realizar las siguientes operaciones:
#
#     - Agregar pasajeros a la lista de viajeros.
#     - Agregar ciudades a la lista de ciudades.
#     - Dado el DNI de un pasajero, ver a qué ciudad viaja.
#     - Dada una ciudad, mostrar la cantidad de pasajeros que viajan a esa ciudad.
#     - Dado el DNI de un pasajero, ver a qué país viaja.
#     - Dado un país, mostrar cuántos pasajeros viajan a ese país.
#     - Salir del programa.
